# %% [markdown]
# # Unit 2, Lecture 5: Context-aware agents and testing
#
# The last lecture of Unit 2, and two threads that belong together.
#
# **Memory** is what lets an agent hold a conversation: "route this to billing"
# then "make it urgent" only works if the second turn remembers the first.
#
# **Testing** is hard *because* of that history, and because the model words its
# answers differently every run. You cannot assert exact output. So you test the
# things that are stable: the invariants that must always hold.
#
# All offline, no model.

# %% [markdown]
# ## Setup

# %%
import sys

from pathlib import Path
project_root = Path.cwd().parents[1]
sys.path.insert(0, str(project_root / "src"))

# %%
from cse476.context import (
    Session, ContextAgent, needs_context,
    check_invariants, all_passed,
    queue_is_valid, field_present, field_in,
)

agent = ContextAgent()
print("fresh agent, empty session:", agent.session.turns)
# Out:
# fresh agent, empty session: []

# %% [markdown]
# ## 1. An agent that carries context across turns
#
# Watch the second turn understand "it" by looking back at the first.

# %%
print("turn 1:", agent.handle("route ticket 12 to billing"))
print("turn 2:", agent.handle("make it urgent"))
print()
print("what the session pinned:")
print("  queue:   ", agent.session.recall("queue"))
print("  priority:", agent.session.recall("priority"))
# Out:
# turn 1: Routed to the billing team.
# turn 2: Marked the billing ticket urgent.
#
# what the session pinned:
#   queue:    billing
#   priority: urgent

# %% [markdown]
# The word "it" carried no meaning on its own. The session did: it remembered
# that the current ticket was routed to billing, so "make it urgent" resolved to
# "make the billing ticket urgent".

# %% [markdown]
# ## 2. The honest failure
#
# If the very first thing a user says is "make it urgent", there is no earlier
# ticket. A good agent does **not** invent one.

# %%
fresh = ContextAgent()
print(fresh.handle("make it urgent"))
# Out:
# I do not have an earlier ticket to refer to. Please tell me which one.

# %% [markdown]
# ## 3. Memory is bounded, and pinned facts survive trimming
#
# A session keeps two kinds of memory: a **bounded transcript** (oldest turns drop)
# and **pinned facts** kept separate. This is the pinning idea from Unit 1 Lecture
# 3, now given a home.

# %%
# a tiny session that only keeps the last 2 turns
sess = Session(max_turns=2)
sess.remember("queue", "abuse")          # pin a fact

for i in range(5):
    sess.add("user", f"message {i}")

print("transcript (trimmed to 2):")
print(sess.transcript())
print()
print("but the pinned fact survived:", sess.recall("queue"))
# Out:
# transcript (trimmed to 2):
# user: message 3
# user: message 4
#
# but the pinned fact survived: abuse

# %% [markdown]
# The transcript lost everything but the last two turns. The pinned `queue`
# survived, because it lives separately. **If you only kept the transcript, you
# would eventually trim away the one fact you needed.**

# %% [markdown]
# ## 4. Why the obvious test is broken
#
# Here is the test everyone writes first, and why it fails.

# %%
# DO NOT do this. The model words the answer differently every run.
reply = "It is currently 31C in Mumbai with light rain."

# any of these are equally correct answers:
alternatives = [
    "Mumbai is 31 degrees.",
    "Right now in Mumbai: 31C, humid.",
    "The temperature in Mumbai is thirty-one Celsius.",
]
print("would 'exact match' pass on these correct answers?")
for a in alternatives:
    print(f"  {a == reply!s:5}  {a}")
# Out:
# would 'exact match' pass on these correct answers?
#   False  Mumbai is 31 degrees.
#   False  Right now in Mumbai: 31C, humid.
#   False  The temperature in Mumbai is thirty-one Celsius.

# %% [markdown]
# Every one of those is a correct answer. Every one fails an exact-match
# assertion. A test that flakes on correct output is worse than no test, because
# people learn to ignore it.

# %% [markdown]
# ## 5. Test the invariants instead
#
# An invariant is a promise the output must keep, no matter how it is worded. You
# cannot promise the exact sentence, but you can promise the queue is real, the
# priority is valid, and nothing required is missing.

# %%
# a valid triage result, however it was worded
result = {"queue": "billing", "priority": "normal", "assigned_to": "billing-team"}

checks = check_invariants(result, {
    "queue is valid":   queue_is_valid(),
    "priority present": field_present("priority"),
    "priority allowed": field_in("priority", ["normal", "urgent"]),
})

for c in checks:
    print(f"  [{'pass' if c.passed else 'FAIL'}] {c.name}")
print("all passed:", all_passed(checks))
# Out:
#   [pass] queue is valid
#   [pass] priority present
#   [pass] priority allowed
# all passed: True

# %%
# now a result the model might produce on a bad day
bad = {"queue": "the billing dept maybe", "priority": "", "assigned_to": "x"}

checks = check_invariants(bad, {
    "queue is valid":   queue_is_valid(),
    "priority present": field_present("priority"),
})
for c in checks:
    print(f"  [{'pass' if c.passed else 'FAIL'}] {c.name}")
print("all passed:", all_passed(checks), " <- correctly rejected")
# Out:
#   [FAIL] queue is valid
#   [FAIL] priority present
# all passed: False  <- correctly rejected

# %% [markdown]
# This test never flakes. Run it a thousand times, with the answer worded a
# thousand ways, and it passes whenever the answer is valid and fails whenever it
# is not. **That is a test you can trust in CI.** It is last lecture's run log
# grown into a discipline.

# %% [markdown]
# ## Your turn
#
# **1. Break the memory bound.** Set a session `max_turns=3`, hold a 6-turn
# conversation that refers back to turn 1, and watch context get lost. Then pin the
# fact instead and watch it survive. Feel *why* pinning exists.
#
# **2. Write an invariant test.** For your Practical 2 agent, write one test that
# asserts an invariant, not exact output. Run it several times and confirm it
# passes on valid answers regardless of wording.
#
# **3. List three invariants.** Name three things your capstone system must *never*
# violate. These are your test suite today and your safety argument in Unit 6, the
# same idea wearing two hats.

# %%
# your work here

# %%
# !pip install "fastapi[standard]"
# Out:
# Collecting fastapi[standard]
#   Downloading fastapi-0.141.1-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: starlette>=0.46.0 in d:\cse476-agentic-ai\.venv\lib\site-packages (from fastapi[standard]) (1.3.1)
# Requirement already satisfied: pydantic>=2.9.0 in d:\cse476-agentic-ai\.venv\lib\site-packages (from fastapi[standard]) (2.13.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in d:\cse476-agentic-ai\.venv\lib\site-packages (from fastapi[standard]) (4.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\cse476-agentic-ai\.venv\lib\site-packages (from fastapi[standard]) (0.4.2)
# Collecting annotated-doc>=0.0.2 (from fastapi[standard])
#   Downloading annotated_doc-0.0.5-py3-none-any.whl.metadata (6.5 kB)
# Collecting fastapi-cli>=0.0.32 (from fastapi-cli[standard]>=0.0.32; extra == "standard"->fastapi[standard])
#   Downloading fastapi_cli-0.0.32-py3-none-any.whl.metadata (6.7 kB)
# Collecting fastar>=0.9.0 (from fastapi[standard])
#   Downloading fastar-0.12.0-cp312-cp312-win_amd64.whl.metadata (4.1 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in d:\cse476-agentic-ai\.venv\lib\site-packages (from fastapi[standard]) (0.28.1)
# Requirement already satisfied: jinja2>=3.1.5 in d:\cse476-agentic-ai\.venv\lib\site-packages (from fastapi[standard]) (3.1.6)
# Requirement already satisfied: python-multipart>=0.0.18 in d:\cse476-agentic-ai\.venv\lib\site-packages (from fastapi[standard]) (0.0.32)
# Collecting email-validator>=2.0.0 (from fastapi[standard])
#   Downloading email_validator-2.3.0-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: uvicorn>=0.12.0 in d:\cse476-agentic-ai\.venv\lib\site-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]) (0.52.1)
# Requirement already satisfied: pydantic-settings>=2.0.0 in d:\cse476-agentic-ai\.venv\lib\site-packages (from fastapi[standard]) (2.14.2)
# Collecting pydantic-extra-types>=2.0.0 (from fastapi[standard])
#   Downloading pydantic_extra_types-2.11.1-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: dnspython>=2.0.0 in d:\cse476-agentic-ai\.venv\lib\site-packages (from email-validator>=2.0.0->fastapi[standard]) (2.8.0)
# Requirement already satisfied: idna>=2.0.0 in d:\cse476-agentic-ai\.venv\lib\site-packages (from email-validator>=2.0.0->fastapi[standard]) (3.18)
# Collecting typer>=0.16.0 (from fastapi-cli>=0.0.32->fastapi-cli[standard]>=0.0.32; extra == "standard"->fastapi[standard])
#   Downloading typer-0.27.1-py3-none-any.whl.metadata (16 kB)
# Collecting rich-toolkit>=0.14.8 (from fastapi-cli>=0.0.32->fastapi-cli[standard]>=0.0.32; extra == "standard"->fastapi[standard])
#   Downloading rich_toolkit-0.20.3-py3-none-any.whl.metadata (1.0 kB)
# Collecting fastapi-cloud-cli>=0.1.1 (from fastapi-cli[standard]>=0.0.32; extra == "standard"->fastapi[standard])
#   Downloading fastapi_cloud_cli-0.23.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: anyio in d:\cse476-agentic-ai\.venv\lib\site-packages (from httpx<1.0.0,>=0.23.0->fastapi[standard]) (4.14.2)
# Requirement already satisfied: certifi in d:\cse476-agentic-ai\.venv\lib\site-packages (from httpx<1.0.0,>=0.23.0->fastapi[standard]) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in d:\cse476-agentic-ai\.venv\lib\site-packages (from httpx<1.0.0,>=0.23.0->fastapi[standard]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\cse476-agentic-ai\.venv\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->fastapi[standard]) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\cse476-agentic-ai\.venv\lib\site-packages (from jinja2>=3.1.5->fastapi[standard]) (3.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\cse476-agentic-ai\.venv\lib\site-packages (from pydantic>=2.9.0->fastapi[standard]) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in d:\cse476-agentic-ai\.venv\lib\site-packages (from pydantic>=2.9.0->fastapi[standard]) (2.46.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in d:\cse476-agentic-ai\.venv\lib\site-packages (from pydantic-settings>=2.0.0->fastapi[standard]) (1.2.2)
# Requirement already satisfied: click>=7.0 in d:\cse476-agentic-ai\.venv\lib\site-packages (from uvicorn>=0.12.0->uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]) (8.4.2)
# Collecting httptools>=0.8.0 (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard])
#   Using cached httptools-0.8.0-cp312-cp312-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: pyyaml>=5.1 in d:\cse476-agentic-ai\.venv\lib\site-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]) (6.0.3)
# Collecting watchfiles>=0.20 (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard])
#   Using cached watchfiles-1.2.0-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: websockets>=13.0 in d:\cse476-agentic-ai\.venv\lib\site-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard
kB ? eta -:--:--
#    -- ------------------------------------- 30.7/520.9 kB ? eta -:--:--
#    -- ------------------------------------- 30.7/520.9 kB ? eta -:--:--
#    ------ -------------------------------- 92.2/520.9 kB 655.4 kB/s eta 0:00:01
#    -------- ----------------------------- 112.6/520.9 kB 656.4 kB/s eta 0:00:01
#    ---------- --------------------------- 143.4/520.9 kB 655.8 kB/s eta 0:00:01
#    ------------ ------------------------- 174.1/520.9 kB 655.4 kB/s eta 0:00:01
#    -------------- ----------------------- 194.6/520.9 kB 655.9 kB/s eta 0:00:01
#    -------------- ----------------------- 194.6/520.9 kB 655.9 kB/s eta 0:00:01
#    -------------- ----------------------- 194.6/520.9 kB 655.9 kB/s eta 0:00:01
#    ----------------- -------------------- 235.5/520.9 kB 554.9 kB/s eta 0:00:01
#    ------------------- ------------------ 266.2/520.9 kB 512.0 kB/s eta 0:00:01
#    -------------------- ----------------- 276.5/520.9 kB 532.5 kB/s eta 0:00:01
#    -------------------- ----------------- 276.5/520.9 kB 532.5 kB/s eta 0:00:01
#    ---------------------- --------------- 307.2/520.9 kB 486.8 kB/s eta 0:00:01
#    ---------------------- --------------- 307.2/520.9 kB 486.8 kB/s eta 0:00:01
#    -------------------------- ----------- 358.4/520.9 kB 484.2 kB/s eta 0:00:01
#    -------------------------- ----------- 358.4/520.9 kB 484.2 kB/s eta 0:00:01
#    ---------------------------- --------- 389.1/520.9 kB 466.0 kB/s eta 0:00:01
#    ---------------------------- --------- 389.1/520.9 kB 466.0 kB/s eta 0:00:01
#    ------------------------------ ------- 419.8/520.9 kB 452.1 kB/s eta 0:00:01
#    ------------------------------ ------- 419.8/520.9 kB 452.1 kB/s eta 0:00:01
#    ---------------------------------- --- 471.0/520.9 kB 453.5 kB/s eta 0:00:01
#    ---------------------------------- --- 471.0/520.9 kB 453.5 kB/s eta 0:00:01
#    ---------------------------------- --- 471.0/520.9 kB 453.5 kB/s eta 0:00:01
#    -------------------------------------- 520.9/520.9 kB 441.7 kB/s eta 0:00:00
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Installing collected packages: shellingham, sentry-sdk, rignore, httptools, fastar, email-validator, detect-installer, annotated-doc, watchfiles, typer, rich-toolkit, pydantic-extra-types, fastapi, fastapi-cloud-cli, fastapi-cli
# Successfully installed annotated-doc-0.0.5 detect-installer-0.1.0 email-validator-2.3.0 fastapi-0.141.1 fastapi-cli-0.0.32 fastapi-cloud-cli-0.23.0 fastar-0.12.0 httptools-0.8.0 pydantic-extra-types-2.11.1 rich-toolkit-0.20.3 rignore-0.8.1 sentry-sdk-2.68.1 shellingham-1.5.4 typer-0.27.1 watchfiles-1.2.0
# [notice] A new release of pip is available: 24.0 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from fastapi import FastAPI

app = FastAPI()


@app.get("/weather")
def weather(city: str):

    result = get_weather(city)

    return {
        "city": city,
        "result": result
    }

# %%
@app.post("/agent")
def run_agent(user_input: str):

    result = agent.run(user_input)

    return {
        "answer": result
    }

# %%
uvicorn l4_context_and_testing:app --reload
# Out:
#   Cell In[16], line 1
#     uvicorn l4_context_and_testing:app --reload
#             ^
# SyntaxError: invalid syntax
